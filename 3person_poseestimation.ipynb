# %%
# =========================
# Cell 0: Install and import face-alignment
# =========================

# !pip install -q face-alignment opencv-python-headless pandas openpyxl

import cv2
import os
import numpy as np
import pandas as pd
import torch
import face_alignment

from google.colab import files
from google.colab.patches import cv2_imshow

print("OpenCV version:", cv2.__version__)
print("Torch version:", torch.__version__)
print("face_alignment imported successfully.")

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Device:", device)

# سازگاری با نسخه‌های مختلف face_alignment
if hasattr(face_alignment.LandmarksType, "TWO_D"):
    LANDMARK_TYPE = face_alignment.LandmarksType.TWO_D
else:
    LANDMARK_TYPE = face_alignment.LandmarksType._2D

fa = face_alignment.FaceAlignment(
    LANDMARK_TYPE,
    flip_input=False,
    device=device
)

print("Face alignment model loaded successfully.")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 101.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mediapipe 0.10.21 requires numpy<2, but you have numpy 2.0.2 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.3 which is incompatible.
# tensorflow 2.20.0 requires protobuf>=5.28.0, but you have protobuf 4.25.8 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.3 which is incompatible.
# gradio 5.50.0 requires pillow<12.0,>=8.0, but you have pillow 12.2.0 which is incompatible.
# grain 0.2.17 requires protobuf>=5.28.3, but you have protobuf 4.25.8 which is incompatible.
# ...

# %%
# !pip install mediapipe
#install file for separate audio and video
# !pip install moviepy

# !pip3 install imageio==2.4.1

# !pip install --upgrade imageio-ffmpeg
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 77.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 8.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 1.4.0
#     Uninstalling absl-py-1.4.0:
#       Successfully uninstalled absl-py-1.4.0
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 28.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for imageio: filename=imageio-2.4.1-py3-none-any.whl size=3303884 sha256=7794b889de593cfa8ffa123799cce57dae37aa437cb4799c7c15252e835fc12b
#   Stored in directory: /root/.cache/pip/wheels/80/b9/62/b4ea29811d14efa100f4c104d87f6df91704f7a202d5df7dba
# Successfully built imageio
# ...
#   Attempting uninstall: imageio
#     Found existing installation: ImageIO 2.37.3
#     Uninstalling ImageIO-2.37.3:
#       Successfully uninstalled ImageIO-2.37.3
# ...

# %%
# !pip install ffmpeg
# !pip install numpy
#==1.19.2
# !pip install scipy
#==1.5.2
# !pip install pandas
#==1.1.3
# !pip install scikit-learn
#==0.23.2
# !pip install h5py
#==2.10.0
# !pip install librosa
#==0.8.0
# !pip install tqdm
#==4.54.1
# !pip install pytorch
#==1.7
# !pip install yaml
#==0.2.5
# !pip install tensorboard
#==2.4.0
# !pip install munch
# !pip install yaml
#==0.2.5
# !pip install pyyaml
#==5.3.1
# !pip install tensorboardx
#==2.1
# !pip install torch
#==1.7.0
# !pip install pytorch-lightning
#==1.1.6
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6083 sha256=d072955a4d66b01eddfa20d17b9a360a3b8682fee38ba77c91205dfc030a85a0
#   Stored in directory: /root/.cache/pip/wheels/26/21/0c/c26e09dff860a9071683e279445262346e008a9a1d2142c4ad
# Successfully built ffmpeg
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for pytorch
#   Running setup.py clean for pytorch
# Failed to build pytorch
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (pytorch)
# ERROR: Could not find a version that satisfies the requirement yaml (from versions: none)
# ERROR: No matching distribution found for yaml
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip3 install keras progressbar keras.utils
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for progressbar: filename=progressbar-2.5-py3-none-any.whl size=12065 sha256=2287c0e11a18312964dc8f0858f4ab0119ddf95a916589d97c3737743ab5375d
#   Stored in directory: /root/.cache/pip/wheels/a5/4d/c7/f3cf0f75c746c219090060131fe00f1523cc2c5484991f4030
# ...
#   Created wheel for keras.utils: filename=keras_utils-1.0.13-py3-none-any.whl size=2630 sha256=8885d394c21d2f11dd012785be7adc3eaf085b33125811f17b23a4a90934cc18
#   Stored in directory: /root/.cache/pip/wheels/04/e4/c5/8eda37877405e9629bdb31de4ae348a0a7386382d7c3eb5975
# Successfully built progressbar keras.utils
# ...

# %%
# !python /content/drive/MyDrive/lip-movement-net-master/lip-movement-net-master/src/lip_movement_net.py -v lip-movement-net/videos/044598381-carl-rowan-delivering-speech-a.mp4 -p lip-movement-net/models/shape_predictor_68_face_landmarks.dat -m lip-movement-net/models/1_32_False_True_0.25_lip_motion_net_model.h5
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/lip-movement-net-master/lip-movement-net-master/src/lip_movement_net.py", line 24, in <module>
#     import Keras
# ModuleNotFoundError: No module named 'Keras'

# %%
import moviepy
import moviepy.editor as mp
import cv2
# Replace the parameter with the location of the video
video = moviepy.editor.VideoFileClip("/content/drive/MyDrive/00005.mp4")
audio = video.audio
# Replace the parameter with the location along with filename
audio.write_audiofile("/content/drive/MyDrive/sample.mp3")
#get frame per second of video

cap=cv2.VideoCapture("/content/drive/MyDrive/00005.mp4")
fps = cap.get(cv2.CAP_PROP_FPS)
videosecond= (1000/fps)
audiosecond=100
duration=video.duration
print('video',videosecond)
print('audio',audiosecond)
print('duration is :', duration)
if videosecond == audiosecond:
  number = ((duration*1000)/videosecond)
else:
  number=(((duration*1000)/videosecond)/round(audiosecond/videosecond))

print ('number',number)

# %%
# import module
import cv2
import datetime

# create video capture object
data = cv2.VideoCapture('C:/Users/Asus/Documents/videoDuration.mp4')

# count the number of frames
frames = data.get(cv2.CAP_PROP_FRAME_COUNT)
fps = data.get(cv2.CAP_PROP_FPS)

# calculate duration of the video
seconds = round(frames / fps)
video_time = datetime.timedelta(seconds=seconds)
print(f"duration in seconds: {seconds}")
print(f"video time: {video_time}")

# %%
# give selected image from path
import cv2
import mediapipe as mp
import numpy as np
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles
mp_holistic = mp.solutions.holistic

# For static images:
IMAGE_FILES = [2]
frameNr = 400
c=0
with mp_holistic.Holistic(

    static_image_mode=True,
    model_complexity=2,
    enable_segmentation=True,
    refine_face_landmarks=True) as holistic:
  frameNr = frameNr+1
  for idx, file in enumerate(IMAGE_FILES):
    image = cv2.imread('/content/drive/MyDrive/frameout3330.jpg')
    #image = cv2.imread('/content/drive/MyDrive/calibration/data/test video/output33/frame_372.jpg')

    image_height, image_width, _ = image.shape
    # Convert the BGR image to RGB before processing.
    results = holistic.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    print('result',results)
    c=c+1
    if results.pose_landmarks:

      print(
          f'Nose coordinates: ('
          f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.NOSE].x * image_width}, '
          f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.NOSE].y * image_height})'
      )

print(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.MOUTH_LEFT].x* image_width}')
print(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.MOUTH_LEFT].y* image_height}')
annotated_image = image.copy()

# Draw segmentation on the image.
# To improve segmentation around boundaries, consider applying a joint
# bilateral filter to "results.segmentation_mask" with "image".
condition = np.stack((results.segmentation_mask,) * 3, axis=-1) > 0.1
bg_image = np.zeros(image.shape, dtype=np.uint8)
#bg_image[:] = BG_COLOR
annotated_image = np.where(condition, annotated_image, image)
#rint(condition)
# Draw pose, left and right hands, and face landmarks on the image.
mp_drawing.draw_landmarks(
        annotated_image,
        results.face_landmarks,
        mp_holistic.FACEMESH_TESSELATION,
        landmark_drawing_spec=None,
        connection_drawing_spec=mp_drawing_styles
        .get_default_face_mesh_tesselation_style())
mp_drawing.draw_landmarks(
        annotated_image,
        results.pose_landmarks,
        mp_holistic.POSE_CONNECTIONS,
        landmark_drawing_spec=mp_drawing_styles.
        get_default_pose_landmarks_style())

cv2.imwrite('/content/drive/MyDrive/frameout3330.jpg', annotated_image)
print(frameNr)
# Out:
# result <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Nose coordinates: (288.0320167541504, 192.29970932006836)
# 291.54367446899414
# 197.63717651367188
# 401

# %%
#find floor of room
import cv2
import mediapipe as mp
import numpy as np
from keras.models import model_from_json


#calculate focal length of camera:
focal=640
# give selected image from path
counter = 0
frameNr = 5
s1Px=[]
s1Py=[]
s1Mouthx=[]
s1Mouthy=[]
realdistances1=[]
s2Px=[]
s2Py=[]
s2Mouthx=[]
s2Mouthy=[]
s3Px=[]
s3Py=[]
s3Mouthx=[]
s3Mouthy=[]
realdistances3=[]

for counter in range(1,2):
    mp_drawing = mp.solutions.drawing_utils
    mp_drawing_styles = mp.solutions.drawing_styles
    mp_holistic = mp.solutions.holistic
    scount=1
    for scount in range(1,4):
        if scount==1:
            # For static images:
            IMAGE_FILES = [1]

            with mp_holistic.Holistic(
                static_image_mode=True,
                model_complexity=2,
                enable_segmentation=True,
                refine_face_landmarks=True) as holistic:

                for idx, file in enumerate(IMAGE_FILES):
                    image = cv2.imread(f'/content/drive/MyDrive/calibration/data/test video/output33/frame_{frameNr}.jpg')
                    cv2.imwrite(f'/content/drive/MyDrive/calibration/data/test video/output33/t1.jpg', image)
                    # Convert the BGR image to RGB before processing.
                    image_height, image_width, _ = image.shape
                    results = holistic.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

                    if results.pose_landmarks:
                        print(
                              f'Nose coordinates: ('
                              f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.NOSE].x * image_width}, '
                              f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.NOSE].y * image_height})'
                            )
            s1px=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_FOOT_INDEX].x* image_width}')
            s1px=round(float(s1px))
            s1Px.append(s1px)
            s1py=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_FOOT_INDEX].y* image_height}')
            s1py=round(float(s1py))
            s1Py.append(s1py)
            s1mouthx=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.MOUTH_LEFT].x* image_width}')
            s1mouthx=round(float(s1mouthx))
            s1Mouthx.append(s1mouthx)
            s1mouthy=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.MOUTH_LEFT].y* image_height}')
            s1mouthy=round(float(s1mouthy))
            s1Mouthy.append(s1mouthy)
            annotated_image = image.copy()
            # Draw segmentation on the image.
            # To improve segmentation around boundaries, consider applying a joint
            # bilateral filter to "results.segmentation_mask" with "image".
            condition = np.stack((results.segmentation_mask,) * 3, axis=-1) > 0.1
            bg_image = np.zeros(image.shape, dtype=np.uint8)
            #bg_image[:] = BG_COLOR
            annotated_image = np.where(condition, annotated_image, image)
            #rint(condition)
            # Draw pose, left and right hands, and face landmarks on the image.
            mp_drawing.draw_landmarks(

                annotated_image,
                results.face_landmarks,
                mp_holistic.FACEMESH_TESSELATION,
                landmark_drawing_spec=None,
                connection_drawing_spec=mp_drawing_styles
                .get_default_face_mesh_tesselation_style())
            mp_drawing.draw_landmarks(
                annotated_image,
                results.pose_landmarks,
                mp_holistic.POSE_CONNECTIONS,
                landmark_drawing_spec=mp_drawing_styles.
                get_default_pose_landmarks_style())

            #find distance
            h, w, c = annotated_image.shape
            cv2.imwrite(f'/content/drive/MyDrive/ot.jpg', annotated_image)
            cv2.imwrite(f'/content/drive/MyDrive/out{frameNr}.jpg', annotated_image)



        elif scount==2:
            # For static images:
            IMAGE_FILES = [1]

            with mp_holistic.Holistic(
                static_image_mode=True,
                model_complexity=2,
                enable_segmentation=True,
                refine_face_landmarks=True) as holistic:

                for idx, file in enumerate(IMAGE_FILES):
                    image = cv2.imread(f'/content/drive/MyDrive/calibration/in and out /out{frameNr}.jpg')
                    image_height, image_width, _ = image.shape
                    # Convert the BGR image to RGB before processing.
                    results = holistic.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

                    if results.pose_landmarks:
                        print(
                              f'Nose coordinates: ('
                              f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.NOSE].x * image_width}, '
                              f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.NOSE].y * image_height})'
                            )
            s2px=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_FOOT_INDEX].x* image_width}')
            s2px=round(float(s2px))
            s2Px.append(s2px)
            s2py=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_FOOT_INDEX].y* image_height}')
            s2py=round(float(s2py))
            s2Py.append(s2py)
            s2mouthx=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.MOUTH_LEFT].x* image_width}')
            s2mouthx=round(float(s2mouthx))
            s2Mouthx.append(s2mouthx)
            s2mouthy=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.MOUTH_LEFT].y* image_height}')
            s2mouthy=round(float(s2mouthy))
            s2Mouthy.append(s2mouthy)
            annotated_image = image.copy()
            # Draw segmentation on the image.
            # To improve segmentation around boundaries, consider applying a joint
            # bilateral filter to "results.segmentation_mask" with "image".
            condition = np.stack((results.segmentation_mask,) * 3, axis=-1) > 0.1
            bg_image = np.zeros(image.shape, dtype=np.uint8)
            #bg_image[:] = BG_COLOR
            annotated_image = np.where(condition, annotated_image, image)
            #rint(condition)
            # Draw pose, left and right hands, and face landmarks on the image.
            mp_drawing.draw_landmarks(

                annotated_image,
                results.face_landmarks,
                mp_holistic.FACEMESH_TESSELATION,
                landmark_drawing_spec=None,
                connection_drawing_spec=mp_drawing_styles
                .get_default_face_mesh_tesselation_style())
            mp_drawing.draw_landmarks(
                annotated_image,
                results.pose_landmarks,
                mp_holistic.POSE_CONNECTIONS,
                landmark_drawing_spec=mp_drawing_styles.
                get_default_pose_landmarks_style())

            #find distance
            h, w, c = annotated_image.shape
            cv2.imwrite(f'/content/drive/MyDrive/calibration/in and out /out{frameNr}.jpg', annotated_image)

        if scount==3:
            # For static images:
            IMAGE_FILES = [1]

            with mp_holistic.Holistic(
                static_image_mode=True,
                model_complexity=2,
                enable_segmentation=True,
                refine_face_landmarks=True) as holistic:

                for idx, file in enumerate(IMAGE_FILES):
                    image = cv2.imread(f'/content/drive/MyDrive/calibration/in and out /out{frameNr}.jpg')
                    # Convert the BGR image to RGB before processing.
                    image_height, image_width, _ = image.shape
                    results = holistic.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

                    if results.pose_landmarks:
                        print(
                              f'Nose coordinates: ('
                              f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.NOSE].x * image_width}, '
                              f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.NOSE].y * image_height})'
                            )
            s3px=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_FOOT_INDEX].x* image_width}')
            s3px=round(float(s3px))
            s3Px.append(s3px)
            s3py=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_FOOT_INDEX].y* image_height}')
            s3py=round(float(s3py))
            s3Py.append(s3py)
            s3mouthx=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.MOUTH_LEFT].x* image_width}')
            s3mouthx=round(float(s3mouthx))
            s3Mouthx.append(s3mouthx)
            s3mouthy=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.MOUTH_LEFT].y* image_height}')
            s3mouthy=round(float(s3mouthy))
            s3Mouthy.append(s3mouthy)
            annotated_image = image.copy()
            # Draw segmentation on the image.
            # To improve segmentation around boundaries, consider applying a joint
            # bilateral filter to "results.segmentation_mask" with "image".
            condition = np.stack((results.segmentation_mask,) * 3, axis=-1) > 0.1
            bg_image = np.zeros(image.shape, dtype=np.uint8)
            #bg_image[:] = BG_COLOR
            annotated_image = np.where(condition, annotated_image, image)
            #rint(condition)
            # Draw pose, left and right hands, and face landmarks on the image.
            mp_drawing.draw_landmarks(

                annotated_image,
                results.face_landmarks,
                mp_holistic.FACEMESH_TESSELATION,
                landmark_drawing_spec=None,
                connection_drawing_spec=mp_drawing_styles
                .get_default_face_mesh_tesselation_style())
            mp_drawing.draw_landmarks(
                annotated_image,
                results.pose_landmarks,
                mp_holistic.POSE_CONNECTIONS,
                landmark_drawing_spec=mp_drawing_styles.
                get_default_pose_landmarks_style())

            #find distance
            h, w, c = annotated_image.shape

            cv2.imwrite(f'/content/drive/MyDrive/calibration/in and out /out{frameNr}.jpg', annotated_image)


    frameNr = frameNr+1
cv2.waitKey()
s1ypred=[]
s1MouthX = np.asarray(s1Mouthx)
s1MouthY = np.asarray(s1Mouthy)

#second speaker:
s2ypred=[]
s2MouthX = np.asarray(s2Mouthx)
s2MouthY = np.asarray(s2Mouthy)
#s2Realdistance=np.asarray(s2realdistance)
#third speaker:
s3ypred=[]
s3MouthX = np.asarray(s3Mouthx)
s3MouthY = np.asarray(s3Mouthy)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3799/3069835379.py in <cell line: 0>()
#      27
#      28 for counter in range(1,2):
# ---> 29     mp_drawing = mp.solutions.drawing_utils
#      30     mp_drawing_styles = mp.solutions.drawing_styles
#      31     mp_holistic = mp.solutions.holistic
#
# AttributeError: module 'mediapipe' has no attribute 'solutions'

# %%
#find floor of room
import cv2
import mediapipe as mp
import numpy as np
from keras.models import model_from_json
#read first frame
image = cv2.imread("/content/drive/MyDrive/calibration/frame detect3/frame_650.jpg")
image2 = cv2.imread("/content/drive/MyDrive/calibration/f10.jpg")

h, w, c = image.shape
print('width:  ', w)
print('height: ', h)
print('channel:', c)
# find squres
blur = cv2.pyrMeanShiftFiltering(image2, 20, 25)
gray = cv2.cvtColor(blur, cv2.COLOR_BGR2GRAY)
thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

cnts = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = cnts[0] if len(cnts) == 2 else cnts[1]
var = 1
control_pixel=0
for c in cnts:
    peri = cv2.arcLength(c, True)
    approx = cv2.approxPolyDP(c, 0.09 * peri, True)
    if len(approx) == 4:
        x,y,w,h = cv2.boundingRect(approx)
        if ((w*h)>500 and y>400):
            cv2.rectangle(image,(x,y),(x+w,y+h),(36,255,12),2)
            # find point
            if var == 1:
               x1= x
               y1=y+h
               cv2.circle(image, (x1,y1), radius=2, color=(0, 0, 255), thickness=2)
               var+=1
            elif var == 2:
                x2= x+w
                y2=y+h
                cv2.circle(image, (x2,y2), radius=2, color=(0, 255 , 0), thickness=2)
                var+=1
                control_pixel=w
            elif var == 3:
                x3= x+w
                y3=y+h
                cv2.circle(image, (x3,y3), radius=2, color=(255, 0, 0), thickness=2)
                var+=1
            elif var == 4:
                 x4= x+w
                 y4=y+h
                 cv2.circle(image, (x4,y4), radius=2, color=(0, 0, 0), thickness=2)
#calculate focal length of camera:
room_width=100 #int(input('enter width of room:'))
control_distance=300#int(input('enter first squre distance:'))
control_width=400#int(input('enter width of control box:'))
focal=(control_pixel*control_distance)/control_width
# give selected image from path
counter = 0
frameNr = 1224
s1Px=[]
s1Py=[]
s1Mouthx=[]
s1Mouthy=[]
realdistances1=[]
s2Px=[]
s2Py=[]
s2Mouthx=[]
s2Mouthy=[]
s3Px=[]
s3Py=[]
s3Mouthx=[]
s3Mouthy=[]
realdistances3=[]

for counter in range(1,2):
    mp_drawing = mp.solutions.drawing_utils
    mp_drawing_styles = mp.solutions.drawing_styles
    mp_holistic = mp.solutions.holistic
    scount=1
    for scount in range(1,4):
        if scount==1:
            # For static images:
            IMAGE_FILES = [1]

            with mp_holistic.Holistic(
                static_image_mode=True,
                model_complexity=2,
                enable_segmentation=True,
                refine_face_landmarks=True) as holistic:

                for idx, file in enumerate(IMAGE_FILES):
                    image = cv2.imread(f'/content/drive/MyDrive/calibration/frame detect3/frame_{frameNr}.jpg')
                    cv2.imwrite(f'/content/drive/MyDrive/outtest2222.jpg', image)
                    #draw two lines
                    cv2.line(image, (x1,y1), (x4,y4), (0,0,255), 2)
                    cv2.line(image, (x2,y2), (x3,y3), (255,0,0), 2)
                    image_height, image_width, _ = image.shape

                    # Convert the BGR image to RGB before processing.
                    results = holistic.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

                    if results.pose_landmarks:
                        print(
                              f'Nose coordinates: ('
                              f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.NOSE].x * image_width}, '
                              f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.NOSE].y * image_height})'
                            )
            s1px=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_FOOT_INDEX].x* image_width}')
            s1px=round(float(s1px))
            s1Px.append(s1px)
            s1py=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_FOOT_INDEX].y* image_height}')
            s1py=round(float(s1py))
            s1Py.append(s1py)
            s1mouthx=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.MOUTH_LEFT].x* image_width}')
            s1mouthx=round(float(s1mouthx))
            s1Mouthx.append(s1mouthx)
            s1mouthy=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.MOUTH_LEFT].y* image_height}')
            s1mouthy=round(float(s1mouthy))
            s1Mouthy.append(s1mouthy)
            annotated_image = image.copy()
            # Draw segmentation on the image.
            # To improve segmentation around boundaries, consider applying a joint
            # bilateral filter to "results.segmentation_mask" with "image".
            condition = np.stack((results.segmentation_mask,) * 3, axis=-1) > 0.1
            bg_image = np.zeros(image.shape, dtype=np.uint8)
            #bg_image[:] = BG_COLOR
            annotated_image = np.where(condition, annotated_image, image)
            #rint(condition)
            # Draw pose, left and right hands, and face landmarks on the image.
            mp_drawing.draw_landmarks(

                annotated_image,
                results.face_landmarks,
                mp_holistic.FACEMESH_TESSELATION,
                landmark_drawing_spec=None,
                connection_drawing_spec=mp_drawing_styles
                .get_default_face_mesh_tesselation_style())
            mp_drawing.draw_landmarks(
                annotated_image,
                results.pose_landmarks,
                mp_holistic.POSE_CONNECTIONS,
                landmark_drawing_spec=mp_drawing_styles.
                get_default_pose_landmarks_style())

            #find distance
            h, w, c = annotated_image.shape
            cv2.imwrite(f'/content/drive/MyDrive/outtest.jpg', annotated_image)
            print(s1px)
            print(w)
            for j in range(s1px,w):
              if  ((annotated_image[s1py][j][0]==0) and (annotated_image[s1py][j][1]==0) and (annotated_image[s1py][j][2]==255)):
                  cv2.circle(annotated_image, (j,s1py), radius=2, color=(0,255 , 0), thickness=2)
                  j1=j
            for k in range(s1px,1,-1):
                if  ((annotated_image[s1py][k][0]==255) and (annotated_image[s1py][k][1]==0) and (annotated_image[s1py][k][2]==0)):
                    cv2.circle(annotated_image, (k,s1py), radius=2, color=(0, 0, 255), thickness=2)
                    k1=k
            cv2.imwrite(f'/content/drive/MyDrive/out{frameNr}.jpg', annotated_image)
            room_pixel=j1-k1
            distance=round((focal*room_width)/room_pixel)
            realdistances1.append(distance)


        elif scount==2:
            # For static images:
            IMAGE_FILES = [1]

            with mp_holistic.Holistic(
                static_image_mode=True,
                model_complexity=2,
                enable_segmentation=True,
                refine_face_landmarks=True) as holistic:

                for idx, file in enumerate(IMAGE_FILES):
                    image = cv2.imread(f'/content/drive/MyDrive/calibration/in and out /out{frameNr}.jpg')
                    #draw two lines
                    cv2.line(image, (x1,y1), (x4,y4), (0,0,255), 2)
                    cv2.line(image, (x2,y2), (x3,y3), (255,0,0), 2)
                    image_height, image_width, _ = image.shape

                    # Convert the BGR image to RGB before processing.
                    results = holistic.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

                    if results.pose_landmarks:
                        print(
                              f'Nose coordinates: ('
                              f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.NOSE].x * image_width}, '
                              f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.NOSE].y * image_height})'
                            )
            s2px=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_FOOT_INDEX].x* image_width}')
            s2px=round(float(s2px))
            s2Px.append(s2px)
            s2py=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_FOOT_INDEX].y* image_height}')
            s2py=round(float(s2py))
            s2Py.append(s2py)
            s2mouthx=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.MOUTH_LEFT].x* image_width}')
            s2mouthx=round(float(s2mouthx))
            s2Mouthx.append(s2mouthx)
            s2mouthy=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.MOUTH_LEFT].y* image_height}')
            s2mouthy=round(float(s2mouthy))
            s2Mouthy.append(s2mouthy)
            annotated_image = image.copy()
            # Draw segmentation on the image.
            # To improve segmentation around boundaries, consider applying a joint
            # bilateral filter to "results.segmentation_mask" with "image".
            condition = np.stack((results.segmentation_mask,) * 3, axis=-1) > 0.1
            bg_image = np.zeros(image.shape, dtype=np.uint8)
            #bg_image[:] = BG_COLOR
            annotated_image = np.where(condition, annotated_image, image)
            #rint(condition)
            # Draw pose, left and right hands, and face landmarks on the image.
            mp_drawing.draw_landmarks(

                annotated_image,
                results.face_landmarks,
                mp_holistic.FACEMESH_TESSELATION,
                landmark_drawing_spec=None,
                connection_drawing_spec=mp_drawing_styles
                .get_default_face_mesh_tesselation_style())
            mp_drawing.draw_landmarks(
                annotated_image,
                results.pose_landmarks,
                mp_holistic.POSE_CONNECTIONS,
                landmark_drawing_spec=mp_drawing_styles.
                get_default_pose_landmarks_style())

            #find distance
            h, w, c = annotated_image.shape

            #for j in range(s2px,w):
              #if  ((annotated_image[s2py][j][0]==0) and (annotated_image[s2py][j][1]==0) and (annotated_image[s2py][j][2]==255)):
                  #cv2.circle(annotated_image, (j,s2py), radius=2, color=(0,255 , 0), thickness=2)
                  #j1=j
            #for k in range(s2px,1,-1):
                #if  ((annotated_image[s2py][k][0]==255) and (annotated_image[s2py][k][1]==0) and (annotated_image[s2py][k][2]==0)):
                    #cv2.circle(annotated_image, (k,s2py), radius=2, color=(0, 0, 255), thickness=2)
                    #k1=k
            cv2.imwrite(f'/content/drive/MyDrive/calibration/in and out /out{frameNr}.jpg', annotated_image)
            #room_pixel=j1-k1
            #distance=round((focal*room_width)/room_pixel)
            #realdistance.append(distance)
            #frameNr = frameNr+1

        if scount==3:
            # For static images:
            IMAGE_FILES = [1]

            with mp_holistic.Holistic(
                static_image_mode=True,
                model_complexity=2,
                enable_segmentation=True,
                refine_face_landmarks=True) as holistic:

                for idx, file in enumerate(IMAGE_FILES):
                    image = cv2.imread(f'/content/drive/MyDrive/calibration/in and out /out{frameNr}.jpg')
                    #draw two lines
                    cv2.line(image, (x1,y1), (x4,y4), (0,0,255), 2)
                    cv2.line(image, (x2,y2), (x3,y3), (255,0,0), 2)
                    image_height, image_width, _ = image.shape

                    # Convert the BGR image to RGB before processing.
                    results = holistic.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

                    if results.pose_landmarks:
                        print(
                              f'Nose coordinates: ('
                              f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.NOSE].x * image_width}, '
                              f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.NOSE].y * image_height})'
                            )
            s3px=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_FOOT_INDEX].x* image_width}')
            s3px=round(float(s3px))
            s3Px.append(s3px)
            s3py=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_FOOT_INDEX].y* image_height}')
            s3py=round(float(s3py))
            s3Py.append(s3py)
            s3mouthx=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.MOUTH_LEFT].x* image_width}')
            s3mouthx=round(float(s3mouthx))
            s3Mouthx.append(s3mouthx)
            s3mouthy=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.MOUTH_LEFT].y* image_height}')
            s3mouthy=round(float(s3mouthy))
            s3Mouthy.append(s3mouthy)
            annotated_image = image.copy()
            # Draw segmentation on the image.
            # To improve segmentation around boundaries, consider applying a joint
            # bilateral filter to "results.segmentation_mask" with "image".
            condition = np.stack((results.segmentation_mask,) * 3, axis=-1) > 0.1
            bg_image = np.zeros(image.shape, dtype=np.uint8)
            #bg_image[:] = BG_COLOR
            annotated_image = np.where(condition, annotated_image, image)
            #rint(condition)
            # Draw pose, left and right hands, and face landmarks on the image.
            mp_drawing.draw_landmarks(

                annotated_image,
                results.face_landmarks,
                mp_holistic.FACEMESH_TESSELATION,
                landmark_drawing_spec=None,
                connection_drawing_spec=mp_drawing_styles
                .get_default_face_mesh_tesselation_style())
            mp_drawing.draw_landmarks(
                annotated_image,
                results.pose_landmarks,
                mp_holistic.POSE_CONNECTIONS,
                landmark_drawing_spec=mp_drawing_styles.
                get_default_pose_landmarks_style())

            #find distance
            h, w, c = annotated_image.shape

            #for j in range(s3px,w):
              #if  ((annotated_image[s3py][j][0]==0) and (annotated_image[s3py][j][1]==0) and (annotated_image[s3py][j][2]==255)):
                  #cv2.circle(annotated_image, (j,s3py), radius=2, color=(0,255 , 0), thickness=2)
                  #j1=j
            #for k in range(s3px,1,-1):
                #if  ((annotated_image[s3py][k][0]==255) and (annotated_image[s3py][k][1]==0) and (annotated_image[s3py][k][2]==0)):
                    #cv2.circle(annotated_image, (k,py), radius=2, color=(0, 0, 255), thickness=2)
                    #k1=k
            cv2.imwrite(f'/content/drive/MyDrive/calibration/in and out /out{frameNr}.jpg', annotated_image)
            #room_pixel=j1-k1
            #distance=round((focal*room_width)/room_pixel)
            #s3realdistance.append(distance)


    frameNr = frameNr+1
cv2.waitKey()
s1ypred=[]
s1MouthX = np.asarray(s1Mouthx)
s1MouthY = np.asarray(s1Mouthy)
s1Realdistance=np.asarray(s1realdistance)
#second speaker:
s2ypred=[]
s2MouthX = np.asarray(s2Mouthx)
s2MouthY = np.asarray(s2Mouthy)
#s2Realdistance=np.asarray(s2realdistance)
#third speaker:
s3ypred=[]
s3MouthX = np.asarray(s3Mouthx)
s3MouthY = np.asarray(s3Mouthy)
#s3Realdistance=np.asarray(s3realdistance)
#load pre train model
# load json and create model
json_file = open('/content/drive/MyDrive/calibration/model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("/content/drive/MyDrive/calibration/model.h5")
print("Loaded model from disk")
#find 3d localization
for i in range(0,5):
    s1new_arr = np.array([np.concatenate( ([s1MouthX[i]], [s1MouthY[i]] ,[s1Realdistance[i]]))])
    ypredi = loaded_model.predict(s1new_arr)
    s1ypred.append(ypredi)
print(s1ypred)

# %%
#creat video from images
import cv2
import numpy as np
import glob

frameSize = (848, 480)

out = cv2.VideoWriter('/content/drive/MyDrive/output_video3.avi',cv2.VideoWriter_fourcc(*'DIVX'), 29, frameSize)

for filename in glob.glob('/content/drive/MyDrive/output_pic/*.jpg'):
    img = cv2.imread(filename)
    out.write(img)

out.release()

# %%
#find floor of room
import cv2
import mediapipe as mp
import numpy as np
from keras.models import model_from_json
#read first frame
image = cv2.imread("/content/drive/MyDrive/calibration/frame detect3/frame_650.jpg")
image2 = cv2.imread("/content/drive/MyDrive/calibration/f10.jpg")

h, w, c = image.shape
print('width:  ', w)
print('height: ', h)
print('channel:', c)
# find squres
blur = cv2.pyrMeanShiftFiltering(image2, 20, 25)
gray = cv2.cvtColor(blur, cv2.COLOR_BGR2GRAY)
thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

cnts = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = cnts[0] if len(cnts) == 2 else cnts[1]
var = 1
control_pixel=0
for c in cnts:
    peri = cv2.arcLength(c, True)
    approx = cv2.approxPolyDP(c, 0.09 * peri, True)
    if len(approx) == 4:
        x,y,w,h = cv2.boundingRect(approx)
        if ((w*h)>500 and y>400):
            cv2.rectangle(image,(x,y),(x+w,y+h),(36,255,12),2)
            # find point
            if var == 1:
               x1= x
               y1=y+h
               cv2.circle(image, (x1,y1), radius=2, color=(0, 0, 255), thickness=2)
               var+=1
            elif var == 2:
                x2= x+w
                y2=y+h
                cv2.circle(image, (x2,y2), radius=2, color=(0, 255 , 0), thickness=2)
                var+=1
                control_pixel=w
            elif var == 3:
                x3= x+w
                y3=y+h
                cv2.circle(image, (x3,y3), radius=2, color=(255, 0, 0), thickness=2)
                var+=1
            elif var == 4:
                 x4= x+w
                 y4=y+h
                 cv2.circle(image, (x4,y4), radius=2, color=(0, 0, 0), thickness=2)
#calculate focal length of camera:
room_width=100#int(input('enter width of room:'))
control_distance=300#int(input('enter first squre distance:'))
control_width=400#int(input('enter width of control box:'))
focal=(control_pixel*control_distance)/control_width

# give selected image from path
counter = 0
frameNr = 0
s1Px=[]
s1Py=[]
s1Mouthx=[]
s1Mouthy=[]
realdistances1=[]
s2Px=[]
s2Py=[]
s2Mouthx=[]
s2Mouthy=[]
realdistances2=[]
s3Px=[]
s3Py=[]
s3Mouthx=[]
s3Mouthy=[]
realdistances3=[]

for counter in range(0,200):
    mp_drawing = mp.solutions.drawing_utils
    mp_drawing_styles = mp.solutions.drawing_styles
    mp_holistic = mp.solutions.holistic
    scount=1
    for scount in range(1,4):
        if scount==1:
            # For static images:
            IMAGE_FILES = [1]

            with mp_holistic.Holistic(
                static_image_mode=True,
                model_complexity=2,
                enable_segmentation=True,
                refine_face_landmarks=True) as holistic:

                for idx, file in enumerate(IMAGE_FILES):
                    image = cv2.imread(f'/content/drive/MyDrive/calibration/frame detect3/frame_{frameNr}.jpg')
                    #draw two lines
                    cv2.line(image, (x1,y1), (x4,y4), (0,0,255), 2)
                    cv2.line(image, (x2,y2), (x3,y3), (255,0,0), 2)
                    #cv2.circle(image, (x1,y1), radius=2, color=(0, 255, 255), thickness=2)
                    #cv2.circle(image, (x2,y2), radius=2, color=(0, 255, 255), thickness=2)
                    #cv2.circle(image, (x3,y3), radius=2, color=(0, 0, 255), thickness=2)
                    #cv2.circle(image, (x4,y4), radius=2, color=(0, 0, 255), thickness=2)
                    image_height, image_width, _ = image.shape
                    #cv2.imwrite('/content/drive/MyDrive/otest.jpg',image)
                    # Convert the BGR image to RGB before processing.
                    results = holistic.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

                    if results.pose_landmarks:
                        s1px=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_FOOT_INDEX].x* image_width}')
                        s1px=round(float(s1px))
                        s1Px.append(s1px)
                        s1py=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_FOOT_INDEX].y* image_height}')
                        s1py=round(float(s1py))
                        s1Py.append(s1py)
                        s1mouthx=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.MOUTH_LEFT].x* image_width}')
                        s1mouthx=round(float(s1mouthx))
                        s1Mouthx.append(s1mouthx)
                        s1mouthy=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.MOUTH_LEFT].y* image_height}')
                        s1mouthy=round(float(s1mouthy))
                        s1Mouthy.append(s1mouthy)
                        annotated_image = image.copy()
                        # Draw segmentation on the image.
                        # To improve segmentation around boundaries, consider applying a joint
                        # bilateral filter to "results.segmentation_mask" with "image".
                        condition = np.stack((results.segmentation_mask,) * 3, axis=-1) > 0.1
                        bg_image = np.zeros(image.shape, dtype=np.uint8)
                        #bg_image[:] = BG_COLOR
                        annotated_image = np.where(condition, annotated_image, image)
                        #rint(condition)
                        # Draw pose, left and right hands, and face landmarks on the image.
                        mp_drawing.draw_landmarks(

                            annotated_image,
                            results.face_landmarks,
                            mp_holistic.FACEMESH_TESSELATION,
                            landmark_drawing_spec=None,
                            connection_drawing_spec=mp_drawing_styles
                            .get_default_face_mesh_tesselation_style())
                        mp_drawing.draw_landmarks(
                            annotated_image,
                            results.pose_landmarks,
                            mp_holistic.POSE_CONNECTIONS,
                            landmark_drawing_spec=mp_drawing_styles.
                            get_default_pose_landmarks_style())

                        print('s1px', s1px)
                        print('s1py' , s1py)
                        #find distance
                        h, w, c = annotated_image.shape
                        j1=2
                        k1=1
                        for j in range(s1px,w):
                          if  ((annotated_image[s1py][j][0]==0) and (annotated_image[s1py][j][1]==0) and (annotated_image[s1py][j][2]==255)):
                              cv2.circle(annotated_image, (j,s1py), radius=2, color=(0,255 , 0), thickness=2)
                              j1=j
                              print(j)
                        for k in range(s1px,1,-1):
                            if  ((annotated_image[s1py][k][0]==255) and (annotated_image[s1py][k][1]==0) and (annotated_image[s1py][k][2]==0)):
                                cv2.circle(annotated_image, (k,s1py), radius=2, color=(0, 0, 255), thickness=2)
                                k1=k
                        cv2.imwrite(f'/content/drive/MyDrive/output_pic/output_pic{frameNr}.jpg', annotated_image)
                        room_pixel=j1-k1
                        distance=round((focal*room_width)/room_pixel)
                        realdistances1.append(distance)
                    else:
                        cv2.imwrite(f'/content/drive/MyDrive/output_pic/output_pic{frameNr}.jpg', image)
                        s1px=round(float(0))
                        s1Px.append(s1px)
                        s1py=round(float(0))
                        s1Py.append(s1py)
                        s1mouthx=round(float(0))
                        s1Mouthx.append(s1mouthx)
                        s1mouthy=round(float(0))
                        s1Mouthy.append(s1mouthy)
                        realdistances1.append(0)
        elif scount==2:
                    # For static images:
                    IMAGE_FILES = [1]

                    with mp_holistic.Holistic(
                        static_image_mode=True,
                        model_complexity=2,
                        enable_segmentation=True,
                        refine_face_landmarks=True) as holistic:

                        for idx, file in enumerate(IMAGE_FILES):
                            image = cv2.imread(f'/content/drive/MyDrive/output_pic/output_pic{frameNr}.jpg')
                            #draw two lines
                            cv2.line(image, (x1,y1), (x4,y4), (0,0,255), 2)
                            cv2.line(image, (x2,y2), (x3,y3), (255,0,0), 2)
                            image_height, image_width, _ = image.shape

                            # Convert the BGR image to RGB before processing.
                            results = holistic.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

                            if results.pose_landmarks:
                               s2px=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_FOOT_INDEX].x* image_width}')
                               s2px=round(float(s2px))
                               s2Px.append(s2px)
                               s2py=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_FOOT_INDEX].y* image_height}')
                               s2py=round(float(s2py))
                               s2Py.append(s2py)
                               s2mouthx=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.MOUTH_LEFT].x* image_width}')
                               s2mouthx=round(float(s2mouthx))
                               s2Mouthx.append(s2mouthx)
                               s2mouthy=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.MOUTH_LEFT].y* image_height}')
                               s2mouthy=round(float(s2mouthy))
                               s2Mouthy.append(s2mouthy)
                               annotated_image = image.copy()
                               # Draw segmentation on the image.
                               # To improve segmentation around boundaries, consider applying a joint
                               # bilateral filter to "results.segmentation_mask" with "image".
                               condition = np.stack((results.segmentation_mask,) * 3, axis=-1) > 0.1
                               bg_image = np.zeros(image.shape, dtype=np.uint8)
                               #bg_image[:] = BG_COLOR
                               annotated_image = np.where(condition, annotated_image, image)
                               #rint(condition)
                               # Draw pose, left and right hands, and face landmarks on the image.
                               mp_drawing.draw_landmarks(

                                    annotated_image,
                                    results.face_landmarks,
                                    mp_holistic.FACEMESH_TESSELATION,
                                    landmark_drawing_spec=None,
                                    connection_drawing_spec=mp_drawing_styles
                                    .get_default_face_mesh_tesselation_style())
                               mp_drawing.draw_landmarks(
                                    annotated_image,
                                    results.pose_landmarks,
                                    mp_holistic.POSE_CONNECTIONS,
                                    landmark_drawing_spec=mp_drawing_styles.
                                    get_default_pose_landmarks_style())

                               #find distance
                               h, w, c = annotated_image.shape
                               j1=2
                               k1=1
                               for j in range(s2px,w):
                                 if  ((annotated_image[s2py][j][0]==0) and (annotated_image[s2py][j][1]==0) and (annotated_image[s2py][j][2]==255)):
                                     cv2.circle(annotated_image, (j,s2py), radius=2, color=(0,255 , 0), thickness=2)
                                     j1=j
                               for k in range(s2px,1,-1):
                                   if  ((annotated_image[s2py][k][0]==255) and (annotated_image[s2py][k][1]==0) and (annotated_image[s2py][k][2]==0)):
                                       cv2.circle(annotated_image, (k,s2py), radius=2, color=(0, 0, 255), thickness=2)
                                       k1=k
                               cv2.imwrite(f'/content/drive/MyDrive/calibration/in and out /out{frameNr}.jpg', annotated_image)
                               room_pixel=j1-k1
                               distance=round((focal*room_width)/room_pixel)
                               realdistances2.append(distance)

                            else:
                                s2px=round(float(0))
                                s2Px.append(s2px)
                                s2py=round(float(0))
                                s2Py.append(s2py)
                                s2mouthx=round(float(0))
                                s2Mouthx.append(s2mouthx)
                                s2mouthy=round(float(0))
                                s2Mouthy.append(s2mouthy)
                                realdistances2.append(0)
        elif scount==3:
            # For static images:
            IMAGE_FILES = [1]

            with mp_holistic.Holistic(
                static_image_mode=True,
                model_complexity=2,
                enable_segmentation=True,
                refine_face_landmarks=True) as holistic:

                for idx, file in enumerate(IMAGE_FILES):
                    image = cv2.imread(f'/content/drive/MyDrive/output_pic/output_pic{frameNr}.jpg')
                    #draw two lines
                    cv2.line(image, (x1,y1), (x4,y4), (0,0,255), 2)
                    cv2.line(image, (x2,y2), (x3,y3), (255,0,0), 2)
                    image_height, image_width, _ = image.shape

                    # Convert the BGR image to RGB before processing.
                    results = holistic.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

                    if results.pose_landmarks:
                        s3px=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_FOOT_INDEX].x* image_width}')
                        s3px=round(float(s3px))
                        s3Px.append(s3px)
                        s3py=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_FOOT_INDEX].y* image_height}')
                        s3py=round(float(s3py))
                        s3Py.append(s3py)
                        s3mouthx=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.MOUTH_LEFT].x* image_width}')
                        s3mouthx=round(float(s3mouthx))
                        s3Mouthx.append(s3mouthx)
                        s3mouthy=(f'{results.pose_landmarks.landmark[mp_holistic.PoseLandmark.MOUTH_LEFT].y* image_height}')
                        s3mouthy=round(float(s3mouthy))
                        s3Mouthy.append(s3mouthy)
                        annotated_image = image.copy()
                        # Draw segmentation on the image.
                        # To improve segmentation around boundaries, consider applying a joint
                        # bilateral filter to "results.segmentation_mask" with "image".
                        condition = np.stack((results.segmentation_mask,) * 3, axis=-1) > 0.1
                        bg_image = np.zeros(image.shape, dtype=np.uint8)
                        #bg_image[:] = BG_COLOR
                        annotated_image = np.where(condition, annotated_image, image)
                        #rint(condition)
                        # Draw pose, left and right hands, and face landmarks on the image.
                        mp_drawing.draw_landmarks(

                            annotated_image,
                            results.face_landmarks,
                            mp_holistic.FACEMESH_TESSELATION,
                            landmark_drawing_spec=None,
                            connection_drawing_spec=mp_drawing_styles
                            .get_default_face_mesh_tesselation_style())
                        mp_drawing.draw_landmarks(
                            annotated_image,
                            results.pose_landmarks,
                            mp_holistic.POSE_CONNECTIONS,
                            landmark_drawing_spec=mp_drawing_styles.
                            get_default_pose_landmarks_style())

                        #find distance
                        h, w, c = annotated_image.shape
                        j1=2
                        k1=1
                        for j in range(s3px,w):
                          if  ((annotated_image[s3py][j][0]==0) and (annotated_image[s3py][j][1]==0) and (annotated_image[s3py][j][2]==255)):
                              cv2.circle(annotated_image, (j,s3py), radius=2, color=(0,255 , 0), thickness=2)
                              j1=j
                        for k in range(s3px,1,-1):
                            if  ((annotated_image[s3py][k][0]==255) and (annotated_image[s3py][k][1]==0) and (annotated_image[s3py][k][2]==0)):
                                cv2.circle(annotated_image, (k,s3py), radius=2, color=(0, 0, 255), thickness=2)
                                k1=k
                        cv2.imwrite(f'/content/drive/MyDrive/output_pic/output_pic{frameNr}.jpg', annotated_image)
                        room_pixel=j1-k1
                        distance=round((focal*room_width)/room_pixel)
                        realdistances3.append(distance)

                    else:
                          s3px=round(float(0))
                          s3Px.append(s3px)
                          s3py=round(float(0))
                          s3Py.append(s2py)
                          s3mouthx=round(float(0))
                          s3Mouthx.append(s3mouthx)
                          s3mouthy=round(float(0))
                          s3Mouthy.append(s3mouthy)
                          realdistances3.append(0)
    frameNr = frameNr+1
cv2.waitKey()
s1ypred=[]
s1MouthX = np.asarray(s1Mouthx)
s1MouthY = np.asarray(s1Mouthy)
s1Realdistance=np.asarray(realdistances1)
#second speaker:
s2ypred=[]
s2MouthX = np.asarray(s2Mouthx)
s2MouthY = np.asarray(s2Mouthy)
s2Realdistance=np.asarray(realdistances2)
#third speaker:
s3ypred=[]
s3MouthX = np.asarray(s3Mouthx)
s3MouthY = np.asarray(s3Mouthy)
s3Realdistance=np.asarray(realdistances3)
#load pre train model
# load json and create model
json_file = open('/content/drive/MyDrive/calibration/model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("/content/drive/MyDrive/calibration/model.h5")
print("Loaded model from disk")
#find 3d localization
for i in range(0,3):
    s1new_arr = np.array([np.concatenate( ([s1MouthX[i]], [s1MouthY[i]] ,[s1Realdistance[i]]))])
    ypredi = loaded_model.predict(s1new_arr)
    s1ypred.append(ypredi)
# Out:
# width:   480
# height:  848
# channel: 3

# %%
# read video and creat frame in especial folder
import cv2

capture = cv2.VideoCapture('/content/drive/MyDrive/calibration/data/output3.mp4')

frameNr = 0

while (True):

    success, frame = capture.read()

    if success:
        cv2.imwrite(f'/content/drive/MyDrive/paper pic/frame pic/test_{frameNr}.jpg', frame)

    else:
        break

    frameNr = frameNr+1

capture.release()
print(frameNr)
# Out:
# 122

# %%
#find floor of room

import cv2
import numpy as np
#read first frame
image = cv2.imread("/content/drive/MyDrive/paper pic/frame pic/frame_1000.jpg")
image2 = cv2.imread("/content/drive/MyDrive/paper pic/frame pic/frame_1000.jpg")

h, w, c = image.shape
print('width:  ', w)
print('height: ', h)
print('channel:', c)
# find squres
blur = cv2.pyrMeanShiftFiltering(image2, 20, 25)
gray = cv2.cvtColor(blur, cv2.COLOR_BGR2GRAY)
thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

cnts = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = cnts[0] if len(cnts) == 2 else cnts[1]
var = 1
for c in cnts:
    peri = cv2.arcLength(c, True)
    approx = cv2.approxPolyDP(c, 0.09 * peri, True)
    if len(approx) == 4:
        x,y,w,h = cv2.boundingRect(approx)
        if ((w*h)>500 and y>400):
            cv2.rectangle(image,(x,y),(x+w,y+h),(36,255,12),2)
            # find point
            if var == 1:
               x1= x
               y1=y+h
               cv2.circle(image, (x1,y1), radius=2, color=(0, 0, 255), thickness=2)
               var+=1
            elif var == 2:
                x2= x+w
                y2=y+h
                cv2.circle(image, (x2,y2), radius=2, color=(0, 255 , 0), thickness=2)
                var+=1
            elif var == 3:
                x3= x+w
                y3=y+h
                cv2.circle(image, (x3,y3), radius=2, color=(255, 0, 0), thickness=2)
                var+=1
            elif var == 4:
                 x4= x+w
                 y4=y+h
                 cv2.circle(image, (x4,y4), radius=2, color=(0, 0, 0), thickness=2)
#draw two lines
cv2.line(image, (x1,y1), (x4,y4), (0,0,255), 2)
cv2.line(image, (x2,y2), (x3,y3), (255,0,0), 2)
cv2.imwrite('/content/drive/MyDrive/calibration/o12.png',image)
#painting floor of room
first=[]
last=[]
for j in range(0,1280):
   for i in range(0,720):
       if  ((image[i][j][0]==0) and (image[i][j][1]==0) and (image[i][j][2]==255)):
           image[i][j][0]=50
           image[i][j][1]=50
           image[i][j][2]=50
           first.append([i,j])
       elif  ((image[i][j][0]==255) and (image[i][j][1]==0) and (image[i][j][2]==0)):
           image[i][j][0]=100
           image[i][j][1]=100
           image[i][j][2]=100
           last.append([i,j])
sf=len(first)
sl=len(last)
first=np.array(first)
print(first[0])
last=np.array(last)
print(last[0])
for f1 in range(0,sf):
   for l1 in range(0,sl):
       p1=first[f1,0]
       p2=first[f1,1]
       p3=last[l1,0]
       p4=last[l1,1]
       cv2.line(image, (p2,p1), (p4,p3), (255,0,0), 2)

# draw point of center of lip
v=0
array=np.array([[112,368],[308,254],[212,383]])
cv2.circle(image, (array[2,0],array[2,1]), radius=2, color=(0, 0, 255), thickness=2)
for i in range(array[2,1],h):
    if  ((image[i][array[2,0]][0]==255) and (image[i][array[2,0]][1]==0) and (image[i][array[2,0]][2]==0)):
        cv2.line(image, (array[2,1],array[2,0]), (array[2,1],i),(0, 0, 0), thickness=2)
        cv2.circle(image, (array[2,1],i), radius=2, color=(0, 0, 255), thickness=2)
        m=np.array([array[2,1],i+1])
        v+=1
        break

print(v)
cv2.imwrite('/content/drive/MyDrive/calibration/outtest.png',image)
cv2.imwrite('/content/drive/MyDrive/calibration/o11.png',thresh)
cv2.imwrite('/content/drive/MyDrive/calibration/o12.png',image)

cv2.waitKey()
# Out:
# width:   1280
# height:  720
# channel: 3
# [641 295]
# [715  92]
# 0
# -1

# %%
import cv2
import numpy as np

# Load image, grayscale, median blur, sharpen image
image = cv2.imread('/content/drive/MyDrive/paper pic/frame pic/frame_1000.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blur = cv2.medianBlur(gray, 5)
sharpen_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
sharpen = cv2.filter2D(blur, -1, sharpen_kernel)

# Threshold and morph close
thresh = cv2.threshold(sharpen, 160, 255, cv2.THRESH_BINARY_INV)[1]
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3,3))
close = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel, iterations=2)

# Find contours and filter using threshold area
cnts = cv2.findContours(close, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = cnts[0] if len(cnts) == 2 else cnts[1]

min_area = 100
max_area = 1500
image_number = 0
for c in cnts:
    area = cv2.contourArea(c)
    if area > min_area and area < max_area:
        x,y,w,h = cv2.boundingRect(c)
        ROI = image[y:y+h, x:x+w]
        cv2.imwrite('ROI_{}.png'.format(image_number), ROI)
        cv2.rectangle(image, (x, y), (x + w, y + h), (36,255,12), 2)
        image_number += 1


cv2.imwrite('/content/drive/MyDrive/paper pic/frame pic/f1.png',sharpen)
cv2.imwrite('/content/drive/MyDrive/paper pic/frame pic/f2.png',close)
cv2.imwrite('/content/drive/MyDrive/paper pic/frame pic/f3.png',thresh)
cv2.imwrite('/content/drive/MyDrive/paper pic/frame pic/f4.png',image)
cv2.waitKey()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-30-0494cc9a4dd1> in <cell line: 6>()
#       4 # Load image, grayscale, median blur, sharpen image
#       5 image = cv2.imread('/content/drive/MyDrive/paper pic/frame pic/frame_1000.jpg')
# ----> 6 gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#       7 blur = cv2.medianBlur(gray, 5)
#       8 sharpen_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
#
# error: OpenCV(4.8.0) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# reading image
img = cv2.imread('/content/drive/MyDrive/paper pic/frame pic/frame_20.jpg')

# converting image into grayscale image
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# setting threshold of gray image
_, threshold = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

# using a findContours() function
contours, _ = cv2.findContours(
    threshold, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

i = 0

# list for storing names of shapes
for contour in contours:

    # here we are ignoring first counter because
    # findcontour function detects whole image as shape
    if i == 0:
        i = 1
        continue

    # cv2.approxPloyDP() function to approximate the shape
    approx = cv2.approxPolyDP(
        contour, 0.01 * cv2.arcLength(contour, True), True)

    # using drawContours() function
    cv2.drawContours(img, [contour], 0, (0, 0, 255), 5)

    # finding center point of shape
    M = cv2.moments(contour)
    if M['m00'] != 0.0:
        x = int(M['m10']/M['m00'])
        y = int(M['m01']/M['m00'])



# displaying the image after drawing contours
cv2.imwrite('/content/drive/MyDrive/paper pic/frame pic/f5.png',img)

cv2.waitKey(0)
cv2.destroyAllWindows()
